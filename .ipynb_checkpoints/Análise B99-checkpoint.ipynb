# %%
# Importando as bibliotecas necessárias
from requests import get
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Iniciando a raspagem
url = 'https://www.imdb.com/title/tt0386676/episodes?season=1'
response = get(url)
print(response.text[:250])
# Out:
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#
#         <meta charset="utf-8">
#
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date()

# %%
# Parsing
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
# Mapeando os elementos HTML
episode_containers = html_soup.find_all('div', class_='info')
episode_containers[0].a['title']
episode_containers[0].meta['content']
episode_containers[0].find('div', class_='airdate').text.strip()
episode_containers[0].find('div', class_='ipl-rating-star__rating')
episode_containers[0].find('span', class_='ipl-rating-star__total-votes').text
episode_containers[0].find('div', class_='item_description').text.strip()
# Out:
# 'The premiere episode introduces the boss and staff of the Dunder-Mifflin Paper Company in Scranton, Pennsylvania in a documentary about the workplace.'

# %%
# Loops


theoffice_episodes = []

# Passando pelas páginas
for sn in range(1,10):
    # Request from the server the content of the web page by using get(), and store the server’s response in the variable response
    response = get('https://www.imdb.com/title/tt0386676/episodes?season=' + str(sn))

    # Parsing
    page_html = BeautifulSoup(response.text, 'html.parser')

    # Select all the episode containers from the season's page
    episode_containers = page_html.find_all('div', class_ = 'info')

    # Detalhes dos episódios
    for episodes in episode_containers:
            # Pegando os dados de cada episódio
            season = sn
            episode_number = episodes.meta['content']
            title = episodes.a['title']
            airdate = episodes.find('div', class_='airdate').text.strip()
            rating = episodes.find('span', class_='ipl-rating-star__rating').text
            total_votes = episodes.find('span', class_='ipl-rating-star__total-votes').text
            desc = episodes.find('div', class_='item_description').text.strip()
            # Compilando os dados de cada episódio
            episode_data = [season, episode_number, title, airdate, rating, total_votes, desc]

            # Inserindo os dados no dataset
            theoffice_episodes.append(episode_data)

# %%
# Criando o DataFrame
import pandas as pd 
theoffice_episodes = pd.DataFrame(theoffice_episodes, columns = ['season', 'episode_number', 'title', 'airdate', 'rating', 'total_votes', 'desc'])

theoffice_episodes.head(10)
# Out:
#    season episode_number              title       airdate rating total_votes  \
# 0       1              1              Pilot  25 Mar. 2005    7.3     (8,868)
# 1       1              2      Diversity Day  16 Mar. 2005    8.1     (8,757)
# 2       1              3        Health Care   5 Apr. 2005    7.6     (7,278)
# 3       1              4       The Alliance  12 Apr. 2005    7.8     (7,017)
# 4       1              5         Basketball  19 Apr. 2005    8.2     (7,790)
# 5       1              6           Hot Girl  26 Apr. 2005    7.6     (6,933)
# 6       2              1        The Dundies  20 Sep. 2005    8.6     (7,806)
# 7       2              2  Sexual Harassment  27 Sep. 2005    8.1     (6,708)
# 8       2              3    Office Olympics   4 Oct. 2005    8.2     (6,611)
# 9       2              4           The Fire  11 Oct. 2005    8.2     (6,513)
#
#                                                 desc
# 0  The premiere episode introduces the boss and s...
# 1  Michael's off color remark puts a sensitivity ...
# 2  Michael leaves Dwight in charge of picking the...
# 3  Just for a laugh, Jim agrees to an alliance wi...
# 4  Michael and his staff challenge the warehouse ...
# 5  Michael is just one of the many male staff who...
# 6  Very much unlike his staff, an overeager Micha...
# 7  The office reviews its sexual harassment polic...
# 8  Ready to finalize his deal for a new condo, Mi...
# 9  A fire in the kitchen relegates the staff to t...

# %%
# Limpando os dados

# Transformando o string de total de votos em número
def remove_str(votes):
    for r in ((',',''), ('(',''),(')','')):
        votes = votes.replace(*r)
        
    return votes
theoffice_episodes['total_votes'] = theoffice_episodes.total_votes.apply(remove_str).astype(int)
theoffice_episodes.head()

# Transformando o string de rating em número
theoffice_episodes['rating'] = theoffice_episodes.rating.astype(float)

# Transformando o string de data em datetime
theoffice_episodes['airdate'] = pd.to_datetime(theoffice_episodes.airdate)

theoffice_episodes.info()
theoffice_episodes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   season          188 non-null    int64
#  1   episode_number  188 non-null    object
#  2   title           188 non-null    object
#  3   airdate         188 non-null    datetime64[ns]
#  4   rating          188 non-null    float64
#  5   total_votes     188 non-null    int64
#  6   desc            188 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 10.4+ KB
#    season episode_number          title    airdate  rating  total_votes  \
# 0       1              1          Pilot 2005-03-24     7.3         8848
# 1       1              2  Diversity Day 2005-03-16     8.1         8736
# 2       1              3    Health Care 2005-04-05     7.6         7256
# 3       1              4   The Alliance 2005-04-12     7.8         6998
# 4       1              5     Basketball 2005-04-19     8.2         7767
#
#                                                 desc
# 0  The premiere episode introduces the boss and s...
# 1  Michael's off color remark puts a sensitivity ...
# 2  Michael leaves Dwight in charge of picking the...
# 3  Just for a laugh, Jim agrees to an alliance wi...
# 4  Michael and his staff challenge the warehouse ...

# %%
# Salvando o CSV
dados_serie = theoffice_episodes.to_csv('The_Office_IMDB.csv',index=False)

# %%
# Importando mais bibliotecas
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Regressão linear
dados = pd.read_csv('The_Office_IMDB.csv')
print(dados.head(1))

# %%
# Regressão Linear 2
X = dados.iloc[:, 5].values.reshape(-1, 1) 
Y = dados.iloc[:, 4].values.reshape(-1, 1)  
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X) 

r2 = linear_regressor.score(X,Y)
print("Coeficiente de determinação = ",r2)

# %%
# Gráfico da regressão linear
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.suptitle(dados_serie)
plt.title("R² = "+ "{:.2f}".format(r2))
plt.xlabel('Número de votos') 
plt.ylabel('Rating') 
plt.savefig(" Regression.jpeg")
plt.show()

# %%
# Análise exploratória

df = pd.read_csv('The_Office_IMDB.csv')
df.head()
df.describe()

# %%
# Dados por temporada
df.groupby('season').describe()

# %%
# Os piores episódios
df.sort_values('rating').head(10)
# Out:
#      season  episode_number              title     airdate  rating  \
# 159       8              19       Get the Girl  2012-03-15     6.4
# 148       8               8         Gettysburg  2011-11-17     6.6
# 104       6              14         The Banker  2010-01-21     6.7
# 161       8              21         Angry Andy  2012-04-19     6.7
# 169       9               5  Here Comes Treble  2012-10-25     6.7
# 160       8              20      Welcome Party  2012-04-12     6.8
# 162       8              22         Fundraiser  2012-04-26     6.9
# 166       9               2      Roy's Wedding  2012-09-27     6.9
# 179       9              15   Couples Discount  2013-02-07     7.0
# 167       9               3    Andy's Ancestry  2012-10-04     7.1
#
#      total_votes                                               desc
# 159         4180  Andy goes to Tallahassee to tell Erin that he ...
# 148         3911  Andy decides to motivate and inspire everyone ...
# 104         5489  A banker representing a potential buyer comes ...
# 161         4026  Andy and Erin return to Dunder Mifflin, only t...
# 169         3774  On Halloween, the Cornell a Capella group pays...
# 160         3688  Andy tries to break up with his girlfriend aft...
# 162         3542  Andy confronts Robert for the first time after...
# 166         3693  After Roy's wedding, Jim and Pam wonder if the...
# 179         3604  Andy returns after three months to an angry of...
# 167         3650  Nellie plays a trick on Andy after researching...

# %%
# Os melhores episódios
df.sort_values('rating',ascending=False).head(10)
# Out:
#      season  episode_number                  title     airdate  rating  \
# 187       9              23                 Finale  2013-05-16     9.8
# 137       7              21       Goodbye, Michael  2011-04-28     9.8
# 77        5              13          Stress Relief  2009-02-01     9.7
# 186       9              22               A.A.R.M.  2013-05-09     9.4
# 95        6               5        Niagara: Part 2  2009-10-08     9.4
# 59        4               9           Dinner Party  2008-04-10     9.4
# 27        2              22           Casino Night  2006-05-11     9.3
# 134       7              18            Garage Sale  2011-03-24     9.3
# 132       7              16  Threat Level Midnight  2011-02-17     9.3
# 87        5              23                  Broke  2009-04-23     9.2
#
#      total_votes                                               desc
# 187        19119  One year later, Dunder Mifflin employees past ...
# 137        15766  As the office gets ready for Michael's final d...
# 77         14682  Dwight's too-realistic fire alarm gives Stanle...
# 186         7427  Dwight prepares for a marriage proposal and hi...
# 95          6725  Pam is forced to deal with an embarrassing inj...
# 59         10386  Michael invites Jim and Pam and Andy and Angel...
# 27          8293  The Dunder Mifflin crew holds a casino party a...
# 134         7025  Michael plans to propose to Holly the day of t...
# 132         8946  Michael finally finishes his movie "Threat Lev...
# 87          6323  The Michael Scott Paper Company is gaining cli...

# %%
# Nota média por temporada
df.groupby('season').mean()['rating']
# Out:
# season
# 1    7.766667
# 2    8.290909
# 3    8.452174
# 4    8.400000
# 5    8.342308
# 6    8.050000
# 7    8.158333
# 8    7.416667
# 9    7.708696
# Name: rating, dtype: float64

# %%
# Gráfico de relação entre rating e total de votos
sns.set(font_scale=1.5,font='Rubik',style='whitegrid')
plt.figure(figsize=(12,12))
sns.scatterplot(df.rating,df.total_votes,alpha=0.5,s=100)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# WARNING:matplotlib.font_manager:findfont: Font family ['Rubik'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Rubik'] not found. Falling back to DejaVu Sans.

# %%
# Preparando os dados para o heat map

df_heat = pd.pivot_table(data=df,index=['season'],columns=['episode_number'],values=['rating'])

# Preparando as labels
episodenum = [*range(1,28)]
episodenum = [str(x) for x in episodenum]
episodenum
seasonticks = [*range(1,10)]
seasonticks = ['Temporada '+str(x) for x in seasonticks]
seasonticks

# %%
# Criando o gráfico
sns.set(font_scale=3,font='Rubik',style='whitegrid')
plt.figure(figsize=(30,14))
fg = sns.heatmap(df_heat,cmap='coolwarm_r', cbar_kws={'orientation': 'horizontal', 'label': 'IMDb Rating'}, square=True)

# Colocando o eixo x no topo
fg.xaxis.tick_top()
fg.set_xticklabels(episodenum,fontsize=30)
fg.set_yticklabels(seasonticks, rotation=360, horizontalalignment='right',fontsize=30)
# Adicionando mais espaço
fg.tick_params(axis='y', which='major', pad=40)
fg.set_ylabel('')    
fg.set_xlabel('')
fg.set_title('The Office',fontname='ArialBold',fontsize=100,pad=100)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['ArialBold'] not found. Falling back to DejaVu Sans.

# %%
# Salvando o gráfico
fig = fg.get_figure()
fig.savefig('Ratings_episodios.png',dpi=200)
